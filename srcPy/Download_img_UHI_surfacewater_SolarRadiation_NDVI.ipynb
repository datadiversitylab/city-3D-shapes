# %%
# !pip install geemap
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ...

# %%
# !pip install geedim
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ...

# %%
import ee
import geemap
import os
import geedim
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ee.Authenticate()
ee.Initialize(project='ee-pradnyauoa')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Map = geemap.Map()
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
cty = ee.FeatureCollection('projects/ee-pradnyauoa/assets/data')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
cty = ee.FeatureCollection('projects/ee-pradnyauoa/assets/data')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
roi = cty.geometry()
print(roi)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ee.Geometry({
#   "functionInvocationValue": {
#     "functionName": "Collection.geometry",
#     "arguments": {
#       "collection": {
#         "functionInvocationValue": {
#           "functionName": "Collection.loadTable",
# ...

# %%
worldGeometry = ee.Geometry.Polygon([
  [-180, 90],  #// Top-left corner
  [180, 90],   #// Top-right corner
  [180, -90],  #// Bottom-right corner
  [-180, -90]  #// Bottom-left corner
])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# UHI Daytime and Nighttime Annual FY 2018
import ee
image2 = ee.Image('YALE/YCEO/UHI/UHI_yearly_pixel/v4/2018').select(['Daytime', 'Nighttime'])
geemap.download_ee_image(image2, "UHIpxAnnual_2018_DaytimeNighttime_300_300.tif", region = worldGeometry, scale=300)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# UHIpxAnnual_2018_DaytimeNighttime_300_300.tif: |          | 0.00/1.07M (raw) [  0.0%] in 00:00 (eta:     ?)

# %%
ImgDaytime = image2.select(['Daytime' ])
ImgNighttime = image2.select(['Nighttime' ])


image2BandMean = ee.Image.cat([ImgDaytime , ImgNighttime ]).reduce(ee.Reducer.mean());
geemap.download_ee_image(image2BandMean, "UHIpxAnnual_2018_DayNightBandMean_300m_scale300.tif", region = worldGeometry, scale=300)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ...HIpxAnnual_2018_DayNightBandMean_300m_scale300.tif: |          | 0.00/534k (raw) [  0.0%] in 00:00 (eta:   …

# %%
# UHI Daytime Annual FY 2018
import ee
image2 = ee.Image('YALE/YCEO/UHI/UHI_yearly_pixel/v4/2018').select(['Daytime'])   #.select(['Daytime', 'Nighttime'])
geemap.download_ee_image(image2, "UHIpxAnnual_2018_Daytime_300_300.tif", region = worldGeometry, scale=300)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# UHIpxAnnual_2018_Daytime_300_300.tif: |          | 0.00/534k (raw) [  0.0%] in 00:00 (eta:     ?)

# %%
# UHI Nighttime Annual FY 2018
import ee

image2 = ee.Image('YALE/YCEO/UHI/UHI_yearly_pixel/v4/2018').select(['Nighttime'])   #.select(['Daytime', 'Nighttime'])

geemap.download_ee_image(image2, "UHIpxAnnual_2018_Nighttime_300_300.tif", region = worldGeometry, scale=300)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# UHIpxAnnual_2018_Nighttime_300_300.tif: |          | 0.00/534k (raw) [  0.0%] in 00:00 (eta:     ?)

# %%
# Surface Water Annual FY 2018
import ee
image2 = ee.Image('JRC/GSW1_4/YearlyHistory/2018')   #.select(['Daytime', 'Nighttime'])

geemap.download_ee_image(image2, "SurfaceWater_2018_30_30.tif", region = worldGeometry, scale=30)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# SurfaceWater_2018_30_30.tif: |          | 0.00/668k (raw) [  0.0%] in 00:00 (eta:     ?)

# %%
# Solar radiation daily May 01 2018
worldGeometry = ee.Geometry.Polygon([
  [-180, 90],  #// Top-left corner
  [180, 90],   #// Top-right corner
  [180, -90],  #// Bottom-right corner
  [-180, -90]  #// Bottom-left corner
])
cty = ee.FeatureCollection('projects/ee-pradnyauoa/assets/data')

out_dir = os.path.expanduser("~/Downloads")
loc = worldGeometry
collection = ee.ImageCollection('MODIS/061/MCD18A1') \
                  .filter(ee.Filter.date('2018-05-01', '2018-05-02'))
geemap.download_ee_image_collection(collection, out_dir, region=worldGeometry, scale=3000)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Total number of images: 1
#
# ...
# WARNING:geedim.download:Consider adjusting `region`, `scale` and/or `dtype` to reduce the 2018_05_01.tif download size (raw: 4.27 GB).
# ...

# %%
# NDVI Annual FY 2018
worldGeometry = ee.Geometry.Polygon([
  [-180, 90],  #// Top-left corner
  [180, 90],   #// Top-right corner
  [180, -90],  #// Bottom-right corner
  [-180, -90]  #// Bottom-left corner
])
cty = ee.FeatureCollection('projects/ee-pradnyauoa/assets/data')

out_dir = os.path.expanduser("~/Downloads")
loc = worldGeometry

collection = ee.ImageCollection('LANDSAT/COMPOSITES/C02/T1_L2_ANNUAL_NDVI').filterDate('2018-01-01', '2018-12-31').select("NDVI");

geemap.download_ee_image_collection(collection, out_dir, region=worldGeometry, scale=30, crs='EPSG:4326')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Total number of images: 1
#
# ...
# 2018.tif: |          | 0.00/5.34M (raw) [  0.0%] in 00:00 (eta:     ?)

# %%
# UHI Daytime Summer FY 2018 Not used in ML
import ee
image2 = ee.Image('YALE/YCEO/UHI/Summer_UHI_yearly_pixel/v4/2018').select(['Daytime'])   #.select(['Daytime', 'Nighttime'])
geemap.download_ee_image(image2, "UHI_Summer_2018_Daytime_300_10.tif", region = worldGeometry, scale=10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# UHI_Summer_2018_Daytime_300_10.tif: |          | 0.00/16.0M (raw) [  0.0%] in 00:00 (eta:     ?)

# %%
# UHI Nighttime Summer FY 2018 Not used in ML
import ee
image2 = ee.Image('YALE/YCEO/UHI/Summer_UHI_yearly_pixel/v4/2018').select(['Nighttime'])   #.select(['Daytime', 'Nighttime'])
geemap.download_ee_image(image2, "UHIpxSummer_2018_Nighttime_300_10.tif", region = worldGeometry, scale=10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# UHIpxSummer_2018_Nighttime_300_10.tif: |          | 0.00/16.0M (raw) [  0.0%] in 00:00 (eta:     ?)

# %%
# UHI Daytime Winter FY 2018 Not used in ML
import ee
image2 = ee.Image('YALE/YCEO/UHI/Winter_UHI_yearly_pixel/v4/2018').select(['Daytime'])   #.select(['Daytime', 'Nighttime'])
geemap.download_ee_image(image2, "UHI_Winter_2018_Daytime_300_10.tif", region = worldGeometry, scale=10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# UHI_Winter_2018_Daytime_300_10.tif: |          | 0.00/16.0M (raw) [  0.0%] in 00:00 (eta:     ?)

# %%
# UHI Nighttime Winter FY 2018 Not used in ML
import ee
image2 = ee.Image('YALE/YCEO/UHI/Winter_UHI_yearly_pixel/v4/2018').select(['Nighttime'])   #.select(['Daytime', 'Nighttime'])
geemap.download_ee_image(image2, "UHI_Winter_2018_Nighttime_300_10.tif", region = worldGeometry, scale=10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# UHI_Winter_2018_Nighttime_300_10.tif: |          | 0.00/16.0M (raw) [  0.0%] in 00:00 (eta:     ?)

# %%
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
